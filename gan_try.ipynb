# %%
from pathlib import Path
import glob
import random
import pathlib
import music21
from music21 import converter, instrument, note, chord
import numpy as np
from keras.utils import np_utils
import pandas as pd
from tensorflow.python.keras.callbacks import ModelCheckpoint
import tensorflow as tf
from tensorflow.python.keras.layers import Dense, Dropout, LSTM, Activation
from tensorflow.python.keras.models import Sequential
import music21.note
from music21 import stream,midi
import os
from PIL import Image


#from img2midi import image2midi
from midi2img import midi2image

# %%
path = 'maestro-v3.0.0-midi/maestro-v3.0.0/2018'
os.chdir(path)
midiz = os.listdir()
midis = []
for midi in midiz:
    midis.append(''+midi)
print(len(midis))
# Out:
# 93

# %%
mf = music21.midi.MidiFile()
mf.open(midis[0]) 
mf.read()
mf.close()
s = music21.midi.translate.midiFileToStream(mf)
s.show('midi')
# Out:
#                 <div id="midiPlayerDiv170305"></div>
#                 <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#                 <script>
#                 require.config({
#                     paths: {
#                         'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                     }
#                 });
#                 require(['music21'], function(music21) {
#                     mp = new music21.miditools.MidiPlayer();
#                     mp.addPlayer("#midiPlayerDiv170305");
#                     mp.base64Load("data:audio/midi;base64,...");
#                 });
#                 </script>

# %%
import os
import numpy as np
import py_midicsv as pm

path = 'C:/Users/Ody/Desktop/Work/ComputerSciencePostgraduate/ComputerSciencePostgraduate/Deep Learning/Music_Generation_Project/music_folder'

os.chdir(path)
midiz = os.listdir()
print(midiz)
midis = []
for midi in midiz:
    midis.append(path+'/'+midi)
print(midis)
    
new_dir = 'C:/Users/Ody/Desktop/Work/ComputerSciencePostgraduate/ComputerSciencePostgraduate/Deep Learning/Music_Generation_Project/img_folder'

for m in midis:
    midi2image(m)
    basewidth = 106
    img_path = m.split('\\')[-1].replace(".midi",".png")
    img_path = new_dir+"/"+img_path
    img = Image.open(path+"/"+"MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1.midi") # PROBLEM
    hsize = 106
    img = img.resize((basewidth,hsize), Image.ANTIALIAS)
    img.save(img_path)
# Out:
# ['MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1.midi', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_0.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_1.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_10.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_11.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_12.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_13.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_14.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_15.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_16.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_17.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_18.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_19.png', 'MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1_Piano_2.png', 'MIDI-Unproces
# ...
